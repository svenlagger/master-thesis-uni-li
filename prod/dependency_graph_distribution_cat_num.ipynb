# %%
import pandas as pd
from pgmpy.estimators import HillClimbSearch, BicScore
import bnlearn as bn
import numpy as np
import json
from collections import defaultdict

data = pd.read_csv('C:/Users/svenl/vs_code_projects/hyperRealDataDescriber/data/credit_score/cleaned_credit_score_v2.csv')

data = data.drop(['ID', 'Customer_ID', 'Name', 'SSN', 'Type_of_Loan'], axis=1)

# %%
sample = data.sample(n=9600, random_state=42)

# %%
model = bn.structure_learning.fit(data, methodtype='hc', scoretype='bic')

# Print out the learned edges
print("Learned network structure (edges):", model['model_edges'])

# Visualize the network
# bn.plot_graphviz(model)
# Out:
# [bnlearn] >Computing best DAG using [hc]
# [bnlearn] >Set scoring type at [bic]
# [bnlearn] >Compute structure scores for model comparison (higher is better).
# Learned network structure (edges): [('Num_of_Delayed_Payment', 'Credit_Mix'), ('Credit_Mix', 'Interest_Rate'), ('Credit_Mix', 'Num_Bank_Accounts'), ('Credit_Mix', 'Payment_of_Min_Amount'), ('Credit_Mix', 'Delay_from_due_date'), ('Credit_Mix', 'Num_of_Loan'), ('Credit_Mix', 'Num_Credit_Inquiries'), ('Credit_Mix', 'Num_Credit_Card'), ('Credit_Mix', 'Credit_History_Age'), ('Credit_Mix', 'Age'), ('Credit_Mix', 'Payment_Behaviour'), ('Payment_of_Min_Amount', 'Num_Credit_Inquiries'), ('Payment_of_Min_Amount', 'Num_of_Loan')]

# %%
bn.plot_graphviz(model)
# Out:
# [setgraphviz] >INFO> System found: windows
# [setgraphviz] >INFO> Set Graphviz path in environment.

# %%
def generate_generation_profile(df, categorical_cols, bn_edges):
    """
    Generates a generation profile from data and a Bayesian network structure.
    
    Parameters:
        df (pd.DataFrame): The original dataset.
        categorical_cols (list): List of column names that are categorical.
        bn_edges (list of tuples): BN structure as (parent, child) edges.
    
    Returns:
        dict: Generation profile containing marginal and conditional parameters.
    """
    # List all variables and deduce numerical columns
    all_vars = list(df.columns)
    numerical_cols = [col for col in all_vars if col not in categorical_cols]

    profile = {"variables": {}, "structure": bn_edges}
    
    # Compute marginal distributions or parameters for each variable.
    for col in all_vars:
        if col in categorical_cols:
            # Compute marginal probabilities for categorical variable.
            marginal = df[col].value_counts(normalize=True).to_dict()
            levels = list(marginal.keys())
            profile["variables"][col] = {
                "type": "categorical",
                "levels": levels,
                "marginal": marginal
            }
        else:
            # For numerical variables, assume a Gaussian distribution.
            mean_val = df[col].mean()
            std_val = df[col].std()
            profile["variables"][col] = {
                "type": "numerical",
                "distribution": "Gaussian",
                "parameters": {"mean": mean_val, "std": std_val}
            }
    
    # Build a dictionary mapping each child to its parent(s) from the BN edges.
    parent_dict = defaultdict(list)
    for parent, child in bn_edges:
        parent_dict[child].append(parent)
    
    # For each variable that has parents, compute the conditional distribution.
    for child, parents in parent_dict.items():
        # Ensure the child is in the dataset.
        if child not in df.columns:
            continue
        # Group the data by the parent variables.
        grouped = df.groupby(parents)
        cond_table = {}
        for group_vals, group_df in grouped:
            # Format the parent's configuration as a string key.
            if not isinstance(group_vals, tuple):
                config_key = f"{parents[0]}={group_vals}"
            else:
                config_key = ",".join([f"{p}={v}" for p, v in zip(parents, group_vals)])
            
            if child in categorical_cols:
                # Compute conditional probabilities for categorical child.
                cond_prob = group_df[child].value_counts(normalize=True).to_dict()
                cond_table[config_key] = cond_prob
            else:
                # For numerical child, compute mean and std conditional on the parent's config.
                mean_val = group_df[child].mean()
                std_val = group_df[child].std()
                cond_table[config_key] = {"mean": mean_val, "std": std_val}
        
        # Save the conditional information in the profile.
        profile["variables"][child]["conditional"] = {
            "parents": parents,
            "table": cond_table
        }
    
    return profile

# Example usage:
# Assume you have a DataFrame 'df' with your dataset.
# Define your categorical columns and the learned BN edges:
categorical_cols = ['Month','Occupation', 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour']
bn_edges = [
    ('Num_of_Delayed_Payment', 'Credit_Mix'), 
    ('Credit_Mix', 'Interest_Rate'), 
    ('Credit_Mix', 'Num_Bank_Accounts'), 
    ('Credit_Mix', 'Payment_of_Min_Amount'), 
    ('Credit_Mix', 'Delay_from_due_date'), 
    ('Credit_Mix', 'Num_of_Loan'), 
    ('Credit_Mix', 'Num_Credit_Inquiries'), 
    ('Credit_Mix', 'Num_Credit_Card'), 
    ('Credit_Mix', 'Credit_History_Age'), 
    ('Credit_Mix', 'Age'), 
    ('Credit_Mix', 'Payment_Behaviour'), 
    ('Payment_of_Min_Amount', 'Num_Credit_Inquiries'), 
    ('Payment_of_Min_Amount', 'Num_of_Loan')
]

# Generate the profile.
profile = generate_generation_profile(data, categorical_cols, bn_edges)

# Output the profile as a JSON formatted string.
print(json.dumps(profile, indent=4, default=lambda x: float(x)))
# Out:
# {
#     "variables": {
#         "Month": {
#             "type": "categorical",
#             "levels": [
#                 "September",
#                 "November",
#                 "December",
#                 "October"
#             ],
#             "marginal": {
#                 "September": 0.2529835055820427,
#                 "November": 0.2506736948088484,
#                 "December": 0.2501110485948651,
#                 "October": 0.24623175101424383
#             }
#         },
#         "Age": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 33.85303088631585,
#                 "std": 10.345456801704989
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad": {
#                         "mean": 30.433391434262948,
#                         "std": 8.816989607707047
#                     },
#                     "Credit_Mix=Good": {
#                         "mean": 37.06299289261026,
#                         "std": 10.683515879524501
#                     },
#                     "Credit_Mix=Standard": {
#                         "mean": 33.49721970774603,
#                         "std": 10.221935487537586
#                     }
#                 }
#             }
#         },
#         "Occupation": {
#             "type": "categorical",
#             "levels": [
#                 "Lawyer",
#                 "Architect",
#                 "Mechanic",
#                 "Engineer",
#                 "Accountant",
#                 "Developer",
#                 "Scientist",
#                 "Entrepreneur",
#                 "Teacher",
#                 "Media_Manager",
#                 "Doctor",
#                 "Journalist",
#                 "Manager",
#                 "Writer",
#                 "Musician"
#             ],
#             "marginal": {
#                 "Lawyer": 0.0701827119547514,
#                 "Architect": 0.06997542124433652,
#                 "Mechanic": 0.06905741952678492,
#                 "Engineer": 0.06834670851964819,
#                 "Accountant": 0.0683170955610175,
#                 "Developer": 0.0673990938434659,
#                 "Scientist": 0.06701412538126685,
#                 "Entrepreneur": 0.0664810921259143,
#                 "Teacher": 0.06606651070508454,
#                 "Media_Manager": 0.06577038111877757,
#                 "Doctor": 0.0655630904083627,
#                 "Journalist": 0.0655630904083627,
#                 "Manager": 0.06381592584915159,
#                 "Writer": 0.06337173146969113,
#                 "Musician": 0.06307560188338417
#             }
#         },
#         "Annual_Income": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 157238.5725715893,
#                 "std": 1304223.5283360912
#             }
#         },
#         "Monthly_Inhand_Salary": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 4011.813584944772,
#                 "std": 2938.012753483886
#             }
#         },
#         "Num_Bank_Accounts": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 5.387604015517191,
#                 "std": 2.5729331370575306
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad": {
#                         "mean": 7.941359561752988,
#                         "std": 1.4196348166076784
#                     },
#                     "Credit_Mix=Good": {
#                         "mean": 2.9353519618342907,
#                         "std": 1.9942242234571375
#                     },
#                     "Credit_Mix=Standard": {
#                         "mean": 5.689900426742532,
#                         "std": 1.8151705151685602
#                     }
#                 }
#             }
#         },
#         "Num_Credit_Card": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 5.529864668779058,
#                 "std": 2.0519933528199665
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad": {
#                         "mean": 7.4154631474103585,
#                         "std": 1.7361293506785804
#                     },
#                     "Credit_Mix=Good": {
#                         "mean": 4.3562457404342325,
#                         "std": 1.7192279022623584
#                     },
#                     "Credit_Mix=Standard": {
#                         "mean": 5.330014224751067,
#                         "std": 1.6925237823316894
#                     }
#                 }
#             }
#         },
#         "Interest_Rate": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 13.891853475080696,
#                 "std": 8.021118345928596
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad": {
#                         "mean": 22.44210657370518,
#                         "std": 5.886857943408278
#                     },
#                     "Credit_Mix=Good": {
#                         "mean": 6.525265310096388,
#                         "std": 3.5407654299314832
#                     },
#                     "Credit_Mix=Standard": {
#                         "mean": 14.343592396223976,
#                         "std": 6.320383326447809
#                     }
#                 }
#             }
#         },
#         "Num_of_Loan": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 3.4732446918771656,
#                 "std": 2.329129097557591
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix",
#                     "Payment_of_Min_Amount"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad,Payment_of_Min_Amount=NM": {
#                         "mean": 6.03405572755418,
#                         "std": 2.0342816469715492
#                     },
#                     "Credit_Mix=Bad,Payment_of_Min_Amount=Yes": {
#                         "mean": 6.013591958091463,
#                         "std": 2.068930223613623
#                     },
#                     "Credit_Mix=Good,Payment_of_Min_Amount=NM": {
#                         "mean": 2.0829187396351574,
#                         "std": 1.3826752966491789
#                     },
#                     "Credit_Mix=Good,Payment_of_Min_Amount=No": {
#                         "mean": 2.08284611141754,
#                         "std": 1.380052003219226
#                     },
#                     "Credit_Mix=Standard,Payment_of_Min_Amount=NM": {
#                         "mean": 3.018716577540107,
#                         "std": 1.8945367824360735
#                     },
#                     "Credit_Mix=Standard,Payment_of_Min_Amount=No": {
#                         "mean": 2.122978436657682,
#                         "std": 1.3833855579073833
#                     },
#                     "Credit_Mix=Standard,Payment_of_Min_Amount=Yes": {
#                         "mean": 3.3522770041400074,
#                         "std": 1.921952122720781
#                     }
#                 }
#             }
#         },
#         "Delay_from_due_date": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 21.038822588764845,
#                 "std": 14.820472795113277
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad": {
#                         "mean": 38.35171812749004,
#                         "std": 14.045337215014918
#                     },
#                     "Credit_Mix=Good": {
#                         "mean": 10.036997371239412,
#                         "std": 7.094410906819161
#                     },
#                     "Credit_Mix=Standard": {
#                         "mean": 19.354002327686537,
#                         "std": 10.238819258252574
#                     }
#                 }
#             }
#         },
#         "Num_of_Delayed_Payment": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 13.456217240664515,
#                 "std": 5.863935156911989
#             }
#         },
#         "Changed_Credit_Limit": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 10.370483283484852,
#                 "std": 6.775877216727833
#             }
#         },
#         "Num_Credit_Inquiries": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 7.287986022683526,
#                 "std": 3.897558204825801
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix",
#                     "Payment_of_Min_Amount"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad,Payment_of_Min_Amount=NM": {
#                         "mean": 11.347781217750258,
#                         "std": 2.816311279814798
#                     },
#                     "Credit_Mix=Bad,Payment_of_Min_Amount=Yes": {
#                         "mean": 11.222851479541271,
#                         "std": 2.7665526595612366
#                     },
#                     "Credit_Mix=Good,Payment_of_Min_Amount=NM": {
#                         "mean": 4.438640132669984,
#                         "std": 2.232717743618797
#                     },
#                     "Credit_Mix=Good,Payment_of_Min_Amount=No": {
#                         "mean": 4.431660231660231,
#                         "std": 2.2382850241290266
#                     },
#                     "Credit_Mix=Standard,Payment_of_Min_Amount=NM": {
#                         "mean": 7.099465240641711,
#                         "std": 3.4870009669975714
#                     },
#                     "Credit_Mix=Standard,Payment_of_Min_Amount=No": {
#                         "mean": 4.481132075471698,
#                         "std": 2.3180643020855523
#                     },
#                     "Credit_Mix=Standard,Payment_of_Min_Amount=Yes": {
#                         "mean": 7.879469326307866,
#                         "std": 3.4283948214513877
#                     }
#                 }
#             }
#         },
#         "Credit_Mix": {
#             "type": "categorical",
#             "levels": [
#                 "Standard",
#                 "Good",
#                 "Bad"
#             ],
#             "marginal": {
#                 "Standard": 0.4579940181823566,
#                 "Good": 0.30415469809588674,
#                 "Bad": 0.23785128372175665
#             },
#             "conditional": {
#                 "parents": [
#                     "Num_of_Delayed_Payment"
#                 ],
#                 "table": {
#                     "Num_of_Delayed_Payment=0": {
#                         "Good": 1.0
#                     },
#                     "Num_of_Delayed_Payment=1": {
#                         "Good": 1.0
#                     },
#                     "Num_of_Delayed_Payment=2": {
#                         "Good": 1.0
#                     },
#                     "Num_of_Delayed_Payment=3": {
#                         "Good": 1.0
#                     },
#                     "Num_of_Delayed_Payment=4": {
#                         "Good": 1.0
#                     },
#                     "Num_of_Delayed_Payment=5": {
#                         "Good": 0.9183098591549296,
#                         "Standard": 0.08169014084507042
#                     },
#                     "Num_of_Delayed_Payment=6": {
#                         "Good": 0.8424657534246576,
#                         "Standard": 0.15753424657534246
#                     },
#                     "Num_of_Delayed_Payment=7": {
#                         "Good": 0.7845373891001267,
#                         "Standard": 0.21546261089987326
#                     },
#                     "Num_of_Delayed_Payment=8": {
#                         "Standard": 0.5518518518518518,
#                         "Good": 0.44814814814814813
#                     },
#                     "Num_of_Delayed_Payment=9": {
#                         "Standard": 0.5786516853932584,
#                         "Good": 0.42134831460674155
#                     },
#                     "Num_of_Delayed_Payment=10": {
#                         "Standard": 0.6220151426907397,
#                         "Good": 0.37798485730926035
#                     },
#                     "Num_of_Delayed_Payment=11": {
#                         "Standard": 0.6409623689080814,
#                         "Good": 0.35903763109191855
#                     },
#                     "Num_of_Delayed_Payment=12": {
#                         "Standard": 0.6232329440688383,
#                         "Good": 0.35279655808236016,
#                         "Bad": 0.023970497848801474
#                     },
#                     "Num_of_Delayed_Payment=13": {
#                         "Standard": 0.7998500749625187,
#                         "Good": 0.13493253373313344,
#                         "Bad": 0.06521739130434782
#                     },
#                     "Num_of_Delayed_Payment=14": {
#                         "Standard": 0.527972027972028,
#                         "Good": 0.2834110334110334,
#                         "Bad": 0.18861693861693862
#                     },
#                     "Num_of_Delayed_Payment=15": {
#                         "Standard": 0.6372492836676218,
#                         "Bad": 0.28939828080229224,
#                         "Good": 0.07335243553008595
#                     },
#                     "Num_of_Delayed_Payment=16": {
#                         "Standard": 0.6171829339567504,
#                         "Bad": 0.32963179427235534,
#                         "Good": 0.053185271770894216
#                     },
#                     "Num_of_Delayed_Payment=17": {
#                         "Standard": 0.5817865429234339,
#                         "Bad": 0.3625290023201856,
#                         "Good": 0.05568445475638051
#                     },
#                     "Num_of_Delayed_Payment=18": {
#                         "Standard": 0.5604142692750288,
#                         "Bad": 0.3866513233601841,
#                         "Good": 0.05293440736478711
#                     },
#                     "Num_of_Delayed_Payment=19": {
#                         "Standard": 0.5441755768148565,
#                         "Bad": 0.4040517726505346,
#                         "Good": 0.05177265053460889
#                     },
#                     "Num_of_Delayed_Payment=20": {
#                         "Standard": 0.5554862842892768,
#                         "Bad": 0.4008728179551122,
#                         "Good": 0.043640897755610975
#                     },
#                     "Num_of_Delayed_Payment=21": {
#                         "Bad": 0.7480314960629921,
#                         "Standard": 0.23509561304836896,
#                         "Good": 0.01687289088863892
#                     },
#                     "Num_of_Delayed_Payment=22": {
#                         "Bad": 0.8176943699731903,
#                         "Standard": 0.16621983914209115,
#                         "Good": 0.0160857908847185
#                     },
#                     "Num_of_Delayed_Payment=23": {
#                         "Bad": 0.9051724137931034,
#                         "Standard": 0.08620689655172414,
#                         "Good": 0.008620689655172414
#                     },
#                     "Num_of_Delayed_Payment=24": {
#                         "Bad": 1.0
#                     },
#                     "Num_of_Delayed_Payment=25": {
#                         "Bad": 1.0
#                     },
#                     "Num_of_Delayed_Payment=26": {
#                         "Bad": 1.0
#                     },
#                     "Num_of_Delayed_Payment=27": {
#                         "Bad": 1.0
#                     },
#                     "Num_of_Delayed_Payment=28": {
#                         "Bad": 1.0
#                     }
#                 }
#             }
#         },
#         "Outstanding_Debt": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 1420.0565015250675,
#                 "std": 1146.597150841156
#             }
#         },
#         "Credit_Utilization_Ratio": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 32.2816169434849,
#                 "std": 5.10894440376485
#             }
#         },
#         "Credit_History_Age": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 18.92400692943232,
#                 "std": 7.929994248121536
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad": {
#                         "mean": 10.991862549800794,
#                         "std": 5.373319308909482
#                     },
#                     "Credit_Mix=Good": {
#                         "mean": 24.454625645019963,
#                         "std": 5.3460528690826425
#                     },
#                     "Credit_Mix=Standard": {
#                         "mean": 19.370534721324194,
#                         "std": 7.081275190059582
#                     }
#                 }
#             }
#         },
#         "Payment_of_Min_Amount": {
#             "type": "categorical",
#             "levels": [
#                 "Yes",
#                 "No",
#                 "NM"
#             ],
#             "marginal": {
#                 "Yes": 0.5238828511356569,
#                 "No": 0.3563327312031745,
#                 "NM": 0.11978441766116853
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad": {
#                         "Yes": 0.8793575697211156,
#                         "NM": 0.12064243027888447
#                     },
#                     "Credit_Mix=Good": {
#                         "No": 0.8825820270664979,
#                         "NM": 0.11741797293350209
#                     },
#                     "Credit_Mix=Standard": {
#                         "Yes": 0.6871847924479504,
#                         "No": 0.19190482348377086,
#                         "NM": 0.12091038406827881
#                     }
#                 }
#             }
#         },
#         "Total_EMI_per_month": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 127.40755959607924,
#                 "std": 205.79039649212962
#             }
#         },
#         "Amount_invested_monthly": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 189.45856377150645,
#                 "std": 188.82926238958845
#             }
#         },
#         "Payment_Behaviour": {
#             "type": "categorical",
#             "levels": [
#                 "Low_spent_Small_value_payments",
#                 "High_spent_Medium_value_payments",
#                 "High_spent_Large_value_payments",
#                 "Low_spent_Medium_value_payments",
#                 "High_spent_Small_value_payments",
#                 "Low_spent_Large_value_payments"
#             ],
#             "marginal": {
#                 "Low_spent_Small_value_payments": 0.2759927744380941,
#                 "High_spent_Medium_value_payments": 0.19272113476857472,
#                 "High_spent_Large_value_payments": 0.14753175989813141,
#                 "Low_spent_Medium_value_payments": 0.14720601735319375,
#                 "High_spent_Small_value_payments": 0.12286416535876099,
#                 "Low_spent_Large_value_payments": 0.11368414818324499
#             },
#             "conditional": {
#                 "parents": [
#                     "Credit_Mix"
#                 ],
#                 "table": {
#                     "Credit_Mix=Bad": {
#                         "Low_spent_Small_value_payments": 0.3454930278884462,
#                         "High_spent_Medium_value_payments": 0.17106573705179282,
#                         "Low_spent_Medium_value_payments": 0.1459163346613546,
#                         "High_spent_Small_value_payments": 0.1236304780876494,
#                         "Low_spent_Large_value_payments": 0.11553784860557768,
#                         "High_spent_Large_value_payments": 0.09835657370517928
#                     },
#                     "Credit_Mix=Good": {
#                         "Low_spent_Small_value_payments": 0.21857657482231527,
#                         "High_spent_Medium_value_payments": 0.21039820854834,
#                         "High_spent_Large_value_payments": 0.19365202998734302,
#                         "Low_spent_Medium_value_payments": 0.15071560704897283,
#                         "High_spent_Small_value_payments": 0.12170187907701295,
#                         "Low_spent_Large_value_payments": 0.10495570051601597
#                     },
#                     "Credit_Mix=Standard": {
#                         "Low_spent_Small_value_payments": 0.27802922539764646,
#                         "High_spent_Medium_value_payments": 0.19222811328074485,
#                         "Low_spent_Medium_value_payments": 0.14554506659769817,
#                         "High_spent_Large_value_payments": 0.1424414845467477,
#                         "High_spent_Small_value_payments": 0.12323807060649165,
#                         "Low_spent_Large_value_payments": 0.11851803957067115
#                     }
#                 }
#             }
#         },
#         "Monthly_Balance": {
#             "type": "numerical",
#             "distribution": "Gaussian",
#             "parameters": {
#                 "mean": 402.34573514169796,
#                 "std": 212.88161071290182
#             }
#         }
#     },
#     "structure": [
#         [
#             "Num_of_Delayed_Payment",
#             "Credit_Mix"
#         ],
#         [
#             "Credit_Mix",
#             "Interest_Rate"
#         ],
#         [
#             "Credit_Mix",
#             "Num_Bank_Accounts"
#         ],
#         [
#             "Credit_Mix",
#             "Payment_of_Min_Amount"
#         ],
#         [
#             "Credit_Mix",
#             "Delay_from_due_date"
#         ],
#         [
#             "Credit_Mix",
#             "Num_of_Loan"
#         ],
#         [
#             "Credit_Mix",
#             "Num_Credit_Inquiries"
#         ],
#         [
#             "Credit_Mix",
#             "Num_Credit_Card"
#         ],
#         [
#             "Credit_Mix",
#             "Credit_History_Age"
#         ],
#         [
#             "Credit_Mix",
#             "Age"
#         ],
#         [
#             "Credit_Mix",
#             "Payment_Behaviour"
#         ],
#         [
#             "Payment_of_Min_Amount",
#             "Num_Credit_Inquiries"
#         ],
#         [
#             "Payment_of_Min_Amount",
#             "Num_of_Loan"
#         ]
#     ]
# }

# %% [markdown]
# # Alternative Package for BN

# %%
# Create a HillClimbSearch instance using only the data
hc = HillClimbSearch(sample)

# Now pass the scoring_method to the estimate() function
best_model = hc.estimate(scoring_method=BicScore(sample), max_indegree=3)

print("Learned network structure (edges):", best_model.edges())
